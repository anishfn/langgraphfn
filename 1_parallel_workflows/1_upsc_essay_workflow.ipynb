# %%
from langgraph.graph import StateGraph, START, END
from langchain_mistralai import ChatMistralAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator
from rich import print

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatMistralAI(model="mistral-small-2506")

# %%
class EvaluationSchema(BaseModel):
  feedback: str = Field(description='Detailed feedback for the essay')
  score: int = Field(description="Score out of 10", ge=0, le=10)

# %%
structured_llm = llm.with_structured_output(EvaluationSchema)

# %%
class UPSCState(TypedDict):
  essay: str

  language_feedback: str
  analysis_feedback: str
  clarity_feedback: str
  overall_feedback: str

  individual_scores: Annotated[list[int], operator.add]
  average_score: float

# %%
def evaluate_language(state: UPSCState) -> UPSCState:
  essay = state['essay']
  prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10\n {essay}"
  
  output = structured_llm.invoke(prompt)

  return {
    'language_feedback': output.feedback,
    'individual_scores': [output.score]
  }

# %%
def evaluate_analysis(state: UPSCState) -> UPSCState:
  essay = state['essay']
  prompt = f"Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10\n {essay}"
  
  output = structured_llm.invoke(prompt)

  return {
    'analysis_feedback': output.feedback,
    'individual_scores': [output.score]
  }

# %%
def evaluate_thopught(state: UPSCState) -> UPSCState:
  essay = state['essay']
  prompt = f"Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10\n {essay}"
  
  output = structured_llm.invoke(prompt)

  return {
    'clarity_feedback': output.feedback,
    'individual_scores': [output.score]
  }

# %%
def final_evaluation(state: UPSCState) -> UPSCState:
  # summary feedback
  language_feedback = state["language_feedback"]
  analysis_feedback = state['analysis_feedback']
  clarity_feedback = state['clarity_feedback']

  prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {language_feedback} \n depth of analysis feedback - {analysis_feedback} \n clarity of thought feedback - {clarity_feedback}'

  overall_feedback = llm.invoke(prompt).content
  
  # average score
  average_score = sum(state['individual_scores'])/len(state['individual_scores'])

  return {
    "overall_feedback": overall_feedback,
    "average_score": average_score
  }

# %%
graph = StateGraph(UPSCState)

# nodes
graph.add_node("evaluate_language", evaluate_language)
graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("evaluate_thopught", evaluate_thopught)
graph.add_node("final_evaluation", final_evaluation)

# edges
graph.add_edge(START, "evaluate_language")
graph.add_edge(START, "evaluate_analysis")
graph.add_edge(START, "evaluate_thopught")

graph.add_edge("evaluate_language", "final_evaluation")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("evaluate_thopught", "final_evaluation")

graph.add_edge("final_evaluation", END)

workflow = graph.compile()

# %%
workflow

# %%
essay = """India and AI Time
Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.
India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.
In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.
But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.
One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.
India must all people together - govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.
If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.
So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

initial_state = {
  'essay': essay,
}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'essay': 'India and AI Time\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\nIndia must all people together - govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay discusses the potential impact of Artificial Intelligence (AI) on India, highlighting both opportunities and challenges. Here are some points of feedback:\n\nStrengths:\n1. **Relevance**: The topic is highly relevant in today\'s tech-driven world.\n2. **Balance**: The essay provides a balanced view, discussing both the benefits and drawbacks of AI.\n3. **Specific Examples**: The author provides specific examples of how AI can be used in various sectors like agriculture, healthcare, and education.\n4. **Call to Action**: The essay ends with a strong call to action, emphasizing the need for collective effort and responsible use of AI.\n\nAreas for Improvement:\n1. **Language and Grammar**: There are several grammatical errors and awkward phrasings that detract from the overall quality. For instance, "new tech call Artificial Intel… something (AI)" could be rephrased as "new technology called Artificial Intelligence (AI)".\n2. **Clarity and Conciseness**: Some sentences are unclear or overly convoluted. Simplifying these would improve readability. For example, "One more big problem is privacy. AI need big big data. Who take care?" could be rephrased as "Another significant issue is privacy. AI requires vast amounts of data. Who will ensure its protection?"\n3. **Spelling and Punctuation**: There are several spelling errors and missing punctuation marks that need correction. For example, "engine-ear" should be "engineers", and "govern" should be "government".\n4. **Structure**: While the essay covers a lot of ground, it could benefit from a clearer structure with distinct paragraphs for each main idea.\n5. **Formal Tone**: The essay could benefit from a more formal tone, especially when discussing serious issues like job loss and privacy.\n\nOverall, the essay presents a thoughtful discussion on the impact of AI in India. With improvements in language, clarity, and structure, it could be even more effective.',
#  'clarity_feedback': "The essay presents a clear and concise overview of the potential benefits and challenges of AI in India. It effectively highlights the country's strengths, such as its skilled workforce and government initiatives, and discusses how AI can be applied in various sectors like agriculture, healthcare, and education. The essay also identifies significant challenges, including the digital divide, job displacement, and privacy concerns. The conclusion emphasizes the importance of collective effort and responsible AI use. However, the essay could benefit from improved grammar and sentence structure for better readability. Additionally, providing specific examples or data could enhance the argument's persuasiveness.",
#  'individual_scores': [7]}
